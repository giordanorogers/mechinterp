# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nnsight import LanguageModel

#model = LanguageModel("meta-llama/Llama-3.3-70B-Instruct")
model = LanguageModel("Qwen/Qwen3-32B")

tokenizer = model.tokenizer
# Out:
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %%
import random

random.seed(9001)

letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

letter_sequences = []

for i in range(4):
    replacement_order_seq = []
    for j in range(20):
        seq_len = 5
        clean_list = random.sample(letters, seq_len)
        remaining_letters = list(set(letters) - set(clean_list))
        patch_list = clean_list.copy()
        patch_list[i] = random.sample(remaining_letters, 1)[0]
        #print(clean_list)
        #print(patch_list)
        #print()
        clean_sentence = " ".join(clean_list)
        patch_sentence = " ".join(patch_list)
        #print(clean_sentence)
        #print(patch_sentence)
        replacement_order_seq.append([clean_sentence, patch_sentence])
    letter_sequences.extend(replacement_order_seq)

print(letter_sequences)
# Out:
# [['B J I C S', 'R J I C S'], ['S T Q B W', 'M T Q B W'], ['T U R Y L', 'Q U R Y L'], ['S Q C R O', 'M Q C R O'], ['T O X M Z', 'P O X M Z'], ['H P E J F', 'S P E J F'], ['U M Q I F', 'P M Q I F'], ['P D Z M U', 'Y D Z M U'], ['A W G U P', 'I W G U P'], ['X Q I B N', 'G Q I B N'], ['L D S W V', 'M D S W V'], ['L Q W J A', 'Y Q W J A'], ['J Y N B Z', 'A Y N B Z'], ['S O D G Z', 'U O D G Z'], ['U D A Z Q', 'F D A Z Q'], ['E V Z L K', 'S V Z L K'], ['H Q J V X', 'L Q J V X'], ['I D N Q Y', 'B D N Q Y'], ['F U X V P', 'M U X V P'], ['E G F H A', 'P G F H A'], ['P G L U H', 'P V L U H'], ['W Z B E V', 'W T B E V'], ['Z D Q F V', 'Z J Q F V'], ['S K H O W', 'S N H O W'], ['P W X H R', 'P Y X H R'], ['T G Z N Q', 'T S Z N Q'], ['D R I A S', 'D X I A S'], ['Q G D T W', 'Q R D T W'], ['N I Q E M', 'N W Q E M'], ['B P A N E', 'B K A N E'], ['U M A L Q', 'U D A L Q'], ['I D U C F', 'I Y U C F'], ['A W H N O', 'A L H N O'], ['J E W T U', 'J A W T U'], ['N B U M S', 'N J U M S'], ['N C R L W', 'N P R L W'], ['P H R A O', 'P N R A O'], ['Y F H J I', 'Y E H J I'], ['W P R V B', 'W F R V B'], ['P D C G M', 'P T C G M'], ['J X I A N', 'J X R A N'], ['Y G A O V', 'Y G N O V'], ['T Y Q G R', 'T Y Z G R'], ['T A U G S', 'T A M G S'], ['F X M U T', 'F X P U T'], ['A Y L N R', 'A Y U N R'], ['J M G N H', 'J M S N H'], ['M N U K Y', 'M N I K Y'], ['J X V R M', 'J X U R M'], ['O K Y D P', 'O K V D P'], ['L K M J X', 'L K Z J X'], ['C L J B X', 'C L D B X'], ['C X U T W', 'C X G T W'], ['X K T Y W', 'X K E Y W'], ['D S P T Q', 'D S V T Q'], ['K L H W N', 'K L R W N'], ['J H G Z W', 'J H V Z W'], ['S V P Y B', 'S V W Y B'], ['D I B G A', 'D I O G A'], ['R Q U O V', 'R Q I O V'], ['N O A B P', 'N O A W P'], ['W G K Q I', 'W G K N I'], ['N L J H Q', 'N L J F Q'], ['Q S U L O', 'Q S U C O'], ['S U H G Z', 'S U H Q Z'], ['K Q T P O', 'K Q T D O'], ['L T W R U', 'L T W B U'], ['E Z O P D', 'E Z O J D'], ['Y S K D V', 'Y S K N V'], ['E C S U B', 'E C S P B'], ['U R T H Q', 'U R T J Q'], ['G H R K X', 'G H R U X'], ['L I X B S', 'L I X P S'], ['D O Y E H', 'D O Y C H'], ['X J O M B', 'X J O S B'], ['H Z U K R', 'H Z U P R'], ['Y S F V U', 'Y S F K U'], ['T Y X N P', 'T Y X E P'], ['Z I Y S J', 'Z I Y F J'], ['H Z I E W', 'H Z I G W']]

# %%
letter_sequences_clean = []
for sentence_pair in letter_sequences:
    clean_sentence_pair = []
    for sentence in sentence_pair:
        sentence_tokenized = tokenizer.encode(sentence)
        if len(sentence_tokenized) != 5:
            counter = 0
            for token in sentence_tokenized:
                counter += 1
                print(f"{counter})", tokenizer.decode(token), "||")
        else:
            clean_sentence_pair.append(sentence)
    letter_sequences_clean.append(clean_sentence_pair)
assert letter_sequences_clean == letter_sequences

# %%
PROMPT_TEMPLATE = "{}. Q: What is the {} character in the previous sentence? Answer in one character only! A:"
OPTIONS = ["first", "second", "third", "fourth"]

# %%
letter_sequences
# Out:
# [['B J I C S', 'R J I C S'],
#  ['S T Q B W', 'M T Q B W'],
#  ['T U R Y L', 'Q U R Y L'],
#  ['S Q C R O', 'M Q C R O'],
#  ['T O X M Z', 'P O X M Z'],
#  ['H P E J F', 'S P E J F'],
#  ['U M Q I F', 'P M Q I F'],
#  ['P D Z M U', 'Y D Z M U'],
#  ['A W G U P', 'I W G U P'],
#  ['X Q I B N', 'G Q I B N'],
#  ['L D S W V', 'M D S W V'],
#  ['L Q W J A', 'Y Q W J A'],
#  ['J Y N B Z', 'A Y N B Z'],
#  ['S O D G Z', 'U O D G Z'],
#  ['U D A Z Q', 'F D A Z Q'],
#  ['E V Z L K', 'S V Z L K'],
#  ['H Q J V X', 'L Q J V X'],
#  ['I D N Q Y', 'B D N Q Y'],
#  ['F U X V P', 'M U X V P'],
#  ['E G F H A', 'P G F H A'],
#  ['P G L U H', 'P V L U H'],
#  ['W Z B E V', 'W T B E V'],
#  ['Z D Q F V', 'Z J Q F V'],
#  ['S K H O W', 'S N H O W'],
#  ['P W X H R', 'P Y X H R'],
#  ['T G Z N Q', 'T S Z N Q'],
#  ['D R I A S', 'D X I A S'],
#  ['Q G D T W', 'Q R D T W'],
#  ['N I Q E M', 'N W Q E M'],
#  ['B P A N E', 'B K A N E'],
#  ['U M A L Q', 'U D A L Q'],
#  ['I D U C F', 'I Y U C F'],
#  ['A W H N O', 'A L H N O'],
#  ['J E W T U', 'J A W T U'],
#  ['N B U M S', 'N J U M S'],
#  ['N C R L W', 'N P R L W'],
#  ['P H R A O', 'P N R A O'],
#  ['Y F H J I', 'Y E H J I'],
#  ['W P R V B', 'W F R V B'],
#  ['P D C G M', 'P T C G M'],
#  ['J X I A N', 'J X R A N'],
#  ['Y G A O V', 'Y G N O V'],
#  ['T Y Q G R', 'T Y Z G R'],
#  ['T A U G S', 'T A M G S'],
#  ['F X M U T', 'F X P U T'],
#  ['A Y L N R', 'A Y U N R'],
#  ['J M G N H', 'J M S N H'],
#  ['M N U K Y', 'M N I K Y'],
#  ['J X V R M', 'J X U R M'],
#  ['O K Y D P', 'O K V D P'],
#  ['L K M J X', 'L K Z J X'],
#  ['C L J B X', 'C L D B X'],
#  ['C X U T W', 'C X G T W'],
#  ['X K T Y W', 'X K E Y W'],
#  ['D S P T Q', 'D S V T Q'],
#  ['K L H W N', 'K L R W N'],
#  ['J H G Z W', 'J H V Z W'],
#  ['S V P Y B', 'S V W Y B'],
#  ['D I B G A', 'D I O G A'],
#  ['R Q U O V', 'R Q I O V'],
#  ['N O A B P', 'N O A W P'],
#  ['W G K Q I', 'W G K N I'],
#  ['N L J H Q', 'N L J F Q'],
#  ['Q S U L O', 'Q S U C O'],
#  ['S U H G Z', 'S U H Q Z'],
#  ['K Q T P O', 'K Q T D O'],
#  ['L T W R U', 'L T W B U'],
#  ['E Z O P D', 'E Z O J D'],
#  ['Y S K D V', 'Y S K N V'],
#  ['E C S U B', 'E C S P B'],
#  ['U R T H Q', 'U R T J Q'],
#  ['G H R K X', 'G H R U X'],
#  ['L I X B S', 'L I X P S'],
#  ['D O Y E H', 'D O Y C H'],
#  ['X J O M B', 'X J O S B'],
#  ['H Z U K R', 'H Z U P R'],
#  ['Y S F V U', 'Y S F K U'],
#  ['T Y X N P', 'T Y X E P'],
#  ['Z I Y S J', 'Z I Y F J'],
#  ['H Z I E W', 'H Z I G W']]

# %%
import torch
import time

correct_count = 0
total_count = 0

OPTION_INDICES = [0,1,2,3]  # Change this index to select different word positions (0 for first, 1 for first, etc.)

valid_sentences = {i: 0 for i in range(len(OPTION_INDICES))}

for idx in OPTION_INDICES:
    valid_sentences_idx = []
    for sentence_pair in letter_sequences[:20]:
        valid_sentence_pair = []
        for sentence in sentence_pair:
            # Get the model's prediction for the next token
            prompt = PROMPT_TEMPLATE.format(sentence, OPTIONS[idx])
            input_ids = model.tokenizer.encode(prompt)
            with model.trace(prompt):
                logits = model.output.logits.save()
            predicted_token_id = logits[0, -1].argmax().item()
            predicted_token = model.tokenizer.decode([predicted_token_id])
            print(f"Prompt: {prompt}")
            print(f"Predicted token: {predicted_token}")
            try:
                print(f"Correct answer: {sentence.split()[idx]}")
            except Exception as e:
                print(e)
                print(sentence.split())
            print("-----")
            if predicted_token.strip().lower() == sentence.split()[idx].lower():
                correct_count += 1
                # Add to valid sentences if correct
                valid_sentence_pair.append(sentence)
            total_count += 1
        valid_sentences_idx.append(valid_sentence_pair)
    valid_sentences[idx] = valid_sentences_idx
# Out:
# Prompt: B J I C S. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  B
# Correct answer: B
# -----
# Prompt: R J I C S. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  R
# Correct answer: R
# -----
# Prompt: S T Q B W. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  S
# Correct answer: S
# -----
# Prompt: M T Q B W. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  M
# Correct answer: M
# -----
# Prompt: T U R Y L. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: T
# -----
# Prompt: Q U R Y L. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Q
# -----
# Prompt: S Q C R O. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  S
# Correct answer: S
# -----
# Prompt: M Q C R O. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: M
# -----
# Prompt: T O X M Z. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: T
# -----
# Prompt: P O X M Z. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  P
# Correct answer: P
# -----
# Prompt: H P E J F. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: H
# -----
# Prompt: S P E J F. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  S
# Correct answer: S
# -----
# Prompt: U M Q I F. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: U
# -----
# Prompt: P M Q I F. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  P
# Correct answer: P
# -----
# Prompt: P D Z M U. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  P
# Correct answer: P
# -----
# Prompt: Y D Z M U. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Y
# Correct answer: Y
# -----
# Prompt: A W G U P. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: A
# -----
# Prompt: I W G U P. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  I
# Correct answer: I
# -----
# Prompt: X Q I B N. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  X
# Correct answer: X
# -----
# Prompt: G Q I B N. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  G
# Correct answer: G
# -----
# Prompt: L D S W V. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: L
# -----
# Prompt: M D S W V. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  M
# Correct answer: M
# -----
# Prompt: L Q W J A. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: L
# -----
# Prompt: Y Q W J A. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Y
# -----
# Prompt: J Y N B Z. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Z
# Correct answer: J
# -----
# Prompt: A Y N B Z. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: A
# -----
# Prompt: S O D G Z. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  S
# Correct answer: S
# -----
# Prompt: U O D G Z. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Z
# Correct answer: U
# -----
# Prompt: U D A Z Q. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Let
# Correct answer: U
# -----
# Prompt: F D A Z Q. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  F
# Correct answer: F
# -----
# Prompt: E V Z L K. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: E
# -----
# Prompt: S V Z L K. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  S
# Correct answer: S
# -----
# Prompt: H Q J V X. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  H
# Correct answer: H
# -----
# Prompt: L Q J V X. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: L
# -----
# Prompt: I D N Q Y. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  I
# Correct answer: I
# -----
# Prompt: B D N Q Y. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  B
# Correct answer: B
# -----
# Prompt: F U X V P. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: F
# -----
# Prompt: M U X V P. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  M
# Correct answer: M
# -----
# Prompt: E G F H A. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: E
# -----
# Prompt: P G F H A. Q: What is the first character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: P
# -----
# Prompt: B J I C S. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  J
# Correct answer: J
# -----
# Prompt: R J I C S. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: J
# -----
# Prompt: S T Q B W. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: T
# -----
# Prompt: M T Q B W. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: T
# -----
# Prompt: T U R Y L. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: U
# -----
# Prompt: Q U R Y L. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: U
# -----
# Prompt: S Q C R O. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Q
# -----
# Prompt: M Q C R O. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Q
# -----
# Prompt: T O X M Z. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: O
# -----
# Prompt: P O X M Z. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  P
# Correct answer: O
# -----
# Prompt: H P E J F. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  P
# Correct answer: P
# -----
# Prompt: S P E J F. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  P
# Correct answer: P
# -----
# Prompt: U M Q I F. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  U
# Correct answer: M
# -----
# Prompt: P M Q I F. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  M
# Correct answer: M
# -----
# Prompt: P D Z M U. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  P
# Correct answer: D
# -----
# Prompt: Y D Z M U. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: D
# -----
# Prompt: A W G U P. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  W
# Correct answer: W
# -----
# Prompt: I W G U P. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  I
# Correct answer: W
# -----
# Prompt: X Q I B N. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  X
# Correct answer: Q
# -----
# Prompt: G Q I B N. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Q
# -----
# Prompt: L D S W V. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: D
# -----
# Prompt: M D S W V. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  D
# Correct answer: D
# -----
# Prompt: L Q W J A. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: Q
# -----
# Prompt: Y Q W J A. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Q
# -----
# Prompt: J Y N B Z. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Y
# Correct answer: Y
# -----
# Prompt: A Y N B Z. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Y
# -----
# Prompt: S O D G Z. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  O
# Correct answer: O
# -----
# Prompt: U O D G Z. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Z
# Correct answer: O
# -----
# Prompt: U D A Z Q. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  D
# Correct answer: D
# -----
# Prompt: F D A Z Q. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  D
# Correct answer: D
# -----
# Prompt: E V Z L K. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  V
# Correct answer: V
# -----
# Prompt: S V Z L K. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: V
# -----
# Prompt: H Q J V X. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  H
# Correct answer: Q
# -----
# Prompt: L Q J V X. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: Q
# -----
# Prompt: I D N Q Y. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  I
# Correct answer: D
# -----
# Prompt: B D N Q Y. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  D
# Correct answer: D
# -----
# Prompt: F U X V P. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  U
# Correct answer: U
# -----
# Prompt: M U X V P. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  U
# Correct answer: U
# -----
# Prompt: E G F H A. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: G
# -----
# Prompt: P G F H A. Q: What is the second character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: G
# -----
# Prompt: B J I C S. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: I
# -----
# Prompt: R J I C S. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: I
# -----
# Prompt: S T Q B W. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: Q
# -----
# Prompt: M T Q B W. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: Q
# -----
# Prompt: T U R Y L. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: R
# -----
# Prompt: Q U R Y L. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: R
# -----
# Prompt: S Q C R O. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: C
# -----
# Prompt: M Q C R O. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: C
# -----
# Prompt: T O X M Z. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: X
# -----
# Prompt: P O X M Z. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: X
# -----
# Prompt: H P E J F. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: E
# -----
# Prompt: S P E J F. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  S
# Correct answer: E
# -----
# Prompt: U M Q I F. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Q
# -----
# Prompt: P M Q I F. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: Q
# -----
# Prompt: P D Z M U. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: Z
# -----
# Prompt: Y D Z M U. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Z
# -----
# Prompt: A W G U P. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: G
# -----
# Prompt: I W G U P. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  I
# Correct answer: G
# -----
# Prompt: X Q I B N. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  X
# Correct answer: I
# -----
# Prompt: G Q I B N. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: I
# -----
# Prompt: L D S W V. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: S
# -----
# Prompt: M D S W V. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: S
# -----
# Prompt: L Q W J A. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: W
# -----
# Prompt: Y Q W J A. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: W
# -----
# Prompt: J Y N B Z. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: N
# -----
# Prompt: A Y N B Z. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: N
# -----
# Prompt: S O D G Z. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: D
# -----
# Prompt: U O D G Z. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Z
# Correct answer: D
# -----
# Prompt: U D A Z Q. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Let
# Correct answer: A
# -----
# Prompt: F D A Z Q. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  D
# Correct answer: A
# -----
# Prompt: E V Z L K. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Z
# -----
# Prompt: S V Z L K. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Z
# -----
# Prompt: H Q J V X. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  H
# Correct answer: J
# -----
# Prompt: L Q J V X. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: J
# -----
# Prompt: I D N Q Y. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  I
# Correct answer: N
# -----
# Prompt: B D N Q Y. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  B
# Correct answer: N
# -----
# Prompt: F U X V P. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: X
# -----
# Prompt: M U X V P. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: X
# -----
# Prompt: E G F H A. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: F
# -----
# Prompt: P G F H A. Q: What is the third character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: F
# -----
# Prompt: B J I C S. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: C
# -----
# Prompt: R J I C S. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: C
# -----
# Prompt: S T Q B W. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: B
# -----
# Prompt: M T Q B W. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: B
# -----
# Prompt: T U R Y L. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: Y
# -----
# Prompt: Q U R Y L. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: Y
# -----
# Prompt: S Q C R O. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: R
# -----
# Prompt: M Q C R O. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: R
# -----
# Prompt: T O X M Z. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  T
# Correct answer: M
# -----
# Prompt: P O X M Z. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: M
# -----
# Prompt: H P E J F. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  H
# Correct answer: J
# -----
# Prompt: S P E J F. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  S
# Correct answer: J
# -----
# Prompt: U M Q I F. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: I
# -----
# Prompt: P M Q I F. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: I
# -----
# Prompt: P D Z M U. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: M
# -----
# Prompt: Y D Z M U. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: M
# -----
# Prompt: A W G U P. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: U
# -----
# Prompt: I W G U P. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  I
# Correct answer: U
# -----
# Prompt: X Q I B N. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  X
# Correct answer: B
# -----
# Prompt: G Q I B N. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: B
# -----
# Prompt: L D S W V. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: W
# -----
# Prompt: M D S W V. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: W
# -----
# Prompt: L Q W J A. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: J
# -----
# Prompt: Y Q W J A. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: J
# -----
# Prompt: J Y N B Z. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Z
# Correct answer: B
# -----
# Prompt: A Y N B Z. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: B
# -----
# Prompt: S O D G Z. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: G
# -----
# Prompt: U O D G Z. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Z
# Correct answer: G
# -----
# Prompt: U D A Z Q. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Let
# Correct answer: Z
# -----
# Prompt: F D A Z Q. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  D
# Correct answer: Z
# -----
# Prompt: E V Z L K. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  V
# Correct answer: L
# -----
# Prompt: S V Z L K. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: L
# -----
# Prompt: H Q J V X. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  H
# Correct answer: V
# -----
# Prompt: L Q J V X. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  L
# Correct answer: V
# -----
# Prompt: I D N Q Y. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  I
# Correct answer: Q
# -----
# Prompt: B D N Q Y. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: Q
# -----
# Prompt: F U X V P. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  To
# Correct answer: V
# -----
# Prompt: M U X V P. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Let
# Correct answer: V
# -----
# Prompt: E G F H A. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  A
# Correct answer: H
# -----
# Prompt: P G F H A. Q: What is the fourth character in the previous sentence? Answer in one character only! A:
# Predicted token:  Q
# Correct answer: H
# -----

# %%
valid_sentences
# Out:
# {0: [['B J I C S', 'R J I C S'],
#   ['S T Q B W', 'M T Q B W'],
#   ['T U R Y L', 'Q U R Y L'],
#   ['S Q C R O'],
#   ['T O X M Z', 'P O X M Z'],
#   ['S P E J F'],
#   ['P M Q I F'],
#   ['P D Z M U', 'Y D Z M U'],
#   ['A W G U P', 'I W G U P'],
#   ['X Q I B N', 'G Q I B N'],
#   ['L D S W V', 'M D S W V'],
#   ['L Q W J A'],
#   [],
#   ['S O D G Z'],
#   ['F D A Z Q'],
#   ['S V Z L K'],
#   ['H Q J V X', 'L Q J V X'],
#   ['I D N Q Y', 'B D N Q Y'],
#   ['M U X V P'],
#   []],
#  1: [['B J I C S'],
#   ['S T Q B W', 'M T Q B W'],
#   [],
#   ['S Q C R O', 'M Q C R O'],
#   [],
#   ['H P E J F', 'S P E J F'],
#   ['P M Q I F'],
#   [],
#   ['A W G U P'],
#   ['G Q I B N'],
#   ['M D S W V'],
#   ['Y Q W J A'],
#   ['J Y N B Z'],
#   ['S O D G Z'],
#   ['U D A Z Q', 'F D A Z Q'],
#   ['E V Z L K'],
#   [],
#   ['B D N Q Y'],
#   ['F U X V P', 'M U X V P'],
#   []],
#  2: [[],
#   [],
#   [],
#   [],
#   [],
#   [],
#   ['U M Q I F'],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []],
#  3: [[],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []]}

# %%
character_sentences = {0: [[],
  ['S T Q B W', 'P T Q B W'],
  ['T U R Y L', 'I U R Y L'],
  ['S Q C R O', 'N Q C R O'],
  ['T O X M Z', 'F O X M Z'],
  ['H P E J F', 'M P E J F'],
  [],
  ['P D Z M U'],
  ['S W G U P'],
  [],
  ['L D S W V', 'F D S W V'],
  [],
  ['J Y N B Z', 'E Y N B Z'],
  ['S O D G Z', 'E O D G Z'],
  ['U D A Z Q', 'X D A Z Q'],
  ['I V Z L K'],
  ['H Q J V X', 'L Q J V X'],
  ['I D N Q Y', 'W D N Q Y'],
  ['F U X V P', 'N U X V P'],
  ['C G F H A']],
 1: [[],
  ['W Z B E V', 'W G B E V'],
  ['Z W Q F V'],
  ['S I H O W'],
  ['P W X H R', 'P A X H R'],
  ['T G Z N Q', 'T W Z N Q'],
  ['D R I A S'],
  ['Q G D T W', 'Q N D T W'],
  ['N I Q E M'],
  ['B P A N E'],
  ['U M A L Q'],
  ['I A U C F'],
  [],
  ['J E W T U', 'J Y W T U'],
  ['N Z U M S'],
  ['N C R L W', 'N I R L W'],
  ['P H R A O', 'P I R A O'],
  ['Y U H J I'],
  ['W P R V B', 'W G R V B'],
  []],
 2: [[],
  ['Y G T O V'],
  [],
  ['T A P G S'],
  [],
  ['A Y L N R', 'A Y W N R'],
  [],
  [],
  ['J X V R M'],
  ['O K Y D P'],
  ['L K M J X'],
  [],
  [],
  [],
  ['D S P T Q'],
  ['K L H W N'],
  [],
  ['S V P Y B', 'S V K Y B'],
  [],
  []],
 3: [[],
  [],
  ['N L J H Q'],
  [],
  [],
  ['K Q T P O'],
  ['L T W R U'],
  ['E Z O P D'],
  [],
  ['E C S I B'],
  [],
  [],
  [],
  ['D O Y S H'],
  [],
  ['H Z U K R'],
  [],
  [],
  [],
  []]}

# %%
group_counts = {}
i = 0
# Loop through each order group
for order_group in character_sentences.values():
    # Create a counter to store the number of remaining sentences in the group
    counter = 0
    # Loop through sentence pairs
    for sentence_pair in order_group:
        # Loop through sentences
        for sentence in sentence_pair:
            counter +=1
    group_counts[i] = counter
    i += 1

group_counts
# Out:
# {0: 28, 1: 25, 2: 11, 3: 7}

# %%
group_accuracies = {}
i = 0
for count in group_counts.values():
    group_accuracies[i] = count / 40
    i += 1
group_accuracies
# Out:
# {0: 0.7, 1: 0.625, 2: 0.275, 3: 0.175}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.suptitle('Qwen-32B Accuracy by Letter of Interest Position')
plt.title("Context Form: 'P D Z M U'")
plt.ylim(0, 1)
plt.bar(
    x=["first", "second", "third", "fourth"],
    height=group_accuracies.values(),
    color=["skyblue", "lightgreen", "salmon", "orange"],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       5 plt.title("Context Form: 'P D Z M U'")
#       6 plt.ylim(0, 1)
#       7 plt.bar(
#       8     x=["first", "second", "third", "fourth"],
# ----> 9     height=group_accuracies.values(),
#      10     color=["skyblue", "lightgreen", "salmon", "orange"],
#      11 )
#
# NameError: name 'group_accuracies' is not defined

# %%
correct_count / total_count
# Out:
# 0.7

# %%
accuracy_dict = {
    "first": 0.7,
    "second": 0.325,
    "third": 0.024,
    "fourth": 0.119,
}

# %%
article_first = [
    ['An artist Jane paints daily', 'The artist Jane paints daily'],
    ['The pet fish swims quickly', 'A pet fish swims quickly'],
    ['An animal fish swims well', 'The animal fish swims well'],
    ['A friend Tom visits often', 'The friend Tom visits often'],
    ['The woman Mary cooks well', 'A woman Mary cooks well'],
    ['A machine cars need fuel', 'The machine cars need fuel'],
    ['An invention cars changed society', 'The invention cars changed society'],
    ['A plant trees loves sun', 'The plant trees loves sun'],
    ['The happy dog is loud', 'A happy dog is loud'],
    ['A gentle breeze blows softly', 'The gentle breeze blows softly'],
    ['The small mouse runs away', 'A small mouse runs away'],
    ['A young child plays happily', 'The young child plays happily'],
    ['An old clock ticks slowly', 'The old clock ticks slowly'],
    ['A new book smells fresh', 'The new book smells fresh'],
    ['The quiet library stays peaceful', 'A quiet library stays peaceful'],
    ['A busy street sounds noisy', 'The busy street sounds noisy'],
    ['The fast train arrives soon', 'A fast train arrives soon'],
    ['A sharp knife cuts easily', 'The sharp knife cuts easily'],
    ['A nice flower smells sweet', 'The nice flower smells sweet'],
    ['A thin wire bends easily', 'The thin wire bends easily'],
]

article_second = [
    ["Jack the boy runs fast", "Jack a boy runs fast"],
    ["Jack a student likes math", "Jack the student likes math"],
    ["Jack an actor plays well", "Jack the actor plays well"],
    ["Jane the girl sings beautifully", "Jane a girl sings beautifully"],
    ["Jane a teacher helps kids", "Jane the teacher helps kids"],
    ["Jane an artist paints daily", "Jane the artist paints daily"],
    ["Fish the pet swims quickly", "Fish a pet swims quickly"],
    ["Fish a creature needs water", "Fish the creature needs water"],
    ["Fish an animal that swims", "Fish the animal that swims"],
    ["Tom the man works hard", "Tom a man works hard"],
    ["Tom a friend visits often", "Tom the friend visits often"],
    ["Tom an employee arrives early", "Tom the employee arrives early"],
    ["Kate the woman cooks well", "Kate a woman cooks well"],
    ["Kate a nurse helps patients", "Kate the nurse helps patients"],
    ["Kate an author writes books", "Kate the author writes books"],
    ["Cars the vehicles move fast", "Cars a vehicles move fast"],
    ["Cars a machine need fuel", "Cars the machine need fuel"],
    ["Cars an invention changed society", "Cars the invention changed society"],
    ["Trees the roots grow deep", "Trees a roots grow deep"],
    ["Trees a sun loving plant", "Trees the sun loving plant"],
    ["Trees an oxygen making organism", "Trees the oxygen making organism"],
    ["Bob the builder works daily", "Bob a builder works daily"],
    ["Bob a farmer grows corn", "Bob the farmer grows corn"],
    ["Bob an engineer designs bridges", "Bob the engineer designs bridges"],
    ["Mary the doctor heals people", "Mary a doctor heals people"],
    ["Mary a lawyer fights cases", "Mary the lawyer fights cases"],
    ["Mary an athlete runs races", "Mary the athlete runs races"],
    ["Mike the chef cooks pasta", "Mike a chef cooks pasta"],
    ["Mike a pilot flies planes", "Mike the pilot flies planes"],
    ["Mike an artist shapes clay", "Mike the artist shapes clay"],
    ["Lisa the singer performs nightly", "Lisa a singer performs nightly"],
    ["Lisa a dancer moves gracefully", "Lisa the dancer moves gracefully"],
    ["Lisa an actress plays roles", "Lisa the actress plays roles"],
    ["Books the items contain knowledge", "Books a items contain knowledge"],
    ["Books a product sells quickly", "Books the product sells quickly"],
    ["Books an object fills shelves", "Books the object fills shelves"],
    ["Phones the devices ring constantly", "Phones a devices ring constantly"],
    ["Phones a gadget needs charging", "Phones the gadget needs charging"],
    ["Phones an invention connects people", "Phones the invention connects people"],
    ["Wind the force moves leaves", "Wind a force moves leaves"],
    ["Wind an element shaking trees", "Wind the element shaking trees"],
    ["Wind an energy powers mills", "Wind the energy powers mills"],
]

article_third = [
    ["Jack is the best boy", "Jack is a best boy"],
    ["Jack is a good boy", "Jack is the good boy"],
    ["Jack is an awesome boy", "Jack is the awesome boy"],
    ["Jane is the best girl", "Jane is a best girl"],
    ["Jane is a good girl", "Jane is the good girl"],
    ["Jane is an awesome girl", "Jane is the awesome girl"],
    ["Fish are the best pets", "Fish are a best pets"],
    ["Fish make a good pet", "Fish make the good pet"],
    ["Fish are an awesome pet", "Fish are the awesome pet"],
    ["Tom is the tallest man", "Tom is a tallest man"],
    ["Tom is a smart guy", "Tom is the smart guy"],
    ["Tom is an old friend", "Tom is the old friend"],
    ["Mary is the best lady", "Mary is a best lady"],
    ["Mary is a kind woman", "Mary is the kind woman"],
    ["Mary is an early bird", "Mary is the early bird"],
    ["Cars are the fastest machines", "Cars are a fastest machines"],
    ["Cars need a new engine", "Cars need the new engine"],
    ["Cars get an oil change", "Cars get the oil change"],
    ["Trees give the best shade", "Trees give a best shade"],
    ["Trees need a good forest", "Trees need the good forest"],
    ["Trees grow an inch yearly", "Trees grow the inch yearly"],
]

article_fourth = [
    ["Jack gives me the ball", "Jack gives me a ball"],
    ["Jack shows me a trick", "Jack shows me the trick"],
    ["Jack tells me an idea", "Jack tells me the idea"],
    ["Jane brings me the book", "Jane brings me a book"],
    ["Jane sends me a letter", "Jane sends me the letter"],
    ["Jane gives me an apple", "Jane gives me the apple"],
    ["Fish make me the happiest", "Fish make me a happiest"],
    ["Fish give me a smile", "Fish give me the smile"],
    ["Fish bring me an escape", "Fish bring me the escape"],
    ["Tom lends me the money", "Tom lends me a money"],
    ["Tom buys me a gift", "Tom buys me the gift"],
    ["Tom owes me an answer", "Tom owes me the answer"],
    ["Mary baked me the cake", "Mary baked me a cake"],
    ["Mary draws me a picture", "Mary draws me the picture"],
    ["Mary sings me an anthem", "Mary sings me the anthem"],
    ["Cars cost me the most", "Cars cost me a most"],
    ["Cars save me a walk", "Cars save me the walk"],
    ["Cars offer me an option", "Cars offer me the option"],
    ["Trees give me the oxygen", "Trees give me an oxygen"],
    ["Trees offer me a refuge", "Trees offer me the refuge"],
    ["Trees provide me an escape", "Trees provide me the escape"],
]

# %%
PROMPT_TEMPLATE = """A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
I can tell a joke. Q: What is the fourth word in the previous sentence? A: a 
{}. Q: What is the {} word in the previous sentence? Answer in one word only! A:"""
OPTIONS = ["first", "second", "third", "fourth"]

# %%
import torch
import gc

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## Get Basline Accuracy

# %%
import torch
import time

correct_count = 0
total_count = 0

OPTION_INDEX = 3  # Change this index to select different word positions (0 for first, 1 for first, etc.)

valid_sentences = []

for sentence_pair in article_fourth[:20]:
    valid_sentence_pair = []
    for sentence in sentence_pair:
        # Get the model's prediction for the next token
        prompt = PROMPT_TEMPLATE.format(sentence, OPTIONS[OPTION_INDEX])
        input_ids = model.tokenizer.encode(prompt)
        with model.trace(prompt):
            logits = model.output.logits.save()
        predicted_token_id = logits[0, -1].argmax().item()
        predicted_token = model.tokenizer.decode([predicted_token_id])
        print(f"Prompt: {prompt}")
        print(f"Predicted token: {predicted_token}")
        print(f"Correct answer: {sentence.split()[OPTION_INDEX]}")
        print("-----")
        if predicted_token.strip().lower() == sentence.split()[OPTION_INDEX].lower():
            correct_count += 1
            # Add to valid sentences if correct
            valid_sentence_pair.append(sentence)
        total_count += 1
    valid_sentences.append(valid_sentence_pair)
# Out:
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# model-00011-of-00017.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00012-of-00017.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00013-of-00017.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00015-of-00017.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00010-of-00017.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00009-of-00017.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00014-of-00017.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00016-of-00017.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00017-of-00017.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/17 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jack gives me the ball. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  ball
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jack gives me a ball. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  ball
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jack shows me a trick. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  trick
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jack shows me the trick. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  trick
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jack tells me an idea. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  idea
# Correct answer: an
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jack tells me the idea. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  idea
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jane brings me the book. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  the
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jane brings me a book. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  a
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jane sends me a letter. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  letter
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jane sends me the letter. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  letter
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jane gives me an apple. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  apple
# Correct answer: an
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Jane gives me the apple. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  the
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Fish make me the happiest. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:
#
#
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Fish make me a happiest. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  a
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Fish give me a smile. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:
#
#
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Fish give me the smile. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  the
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Fish bring me an escape. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  escape
# Correct answer: an
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Fish bring me the escape. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  escape
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Tom lends me the money. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  money
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Tom lends me a money. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  money
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Tom buys me a gift. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  gift
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Tom buys me the gift. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  the
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Tom owes me an answer. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  answer
# Correct answer: an
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Tom owes me the answer. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  answer
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Mary baked me the cake. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  the
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Mary baked me a cake. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  a
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Mary draws me a picture. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  a
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Mary draws me the picture. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  me
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Mary sings me an anthem. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  anthem
# Correct answer: an
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Mary sings me the anthem. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  anthem
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Cars cost me the most. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  most
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Cars cost me a most. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  most
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Cars save me a walk. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  walk
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Cars save me the walk. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  walk
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Cars offer me an option. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  option
# Correct answer: an
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Cars offer me the option. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  option
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Trees give me the oxygen. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  oxygen
# Correct answer: the
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Trees give me an oxygen. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  oxygen
# Correct answer: an
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Trees offer me a refuge. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  refuge
# Correct answer: a
# -----
# Prompt: A ball rolls by quckly. Q: What is the second word in the previous sentence? A: ball
# Have an awesome day today. Q: What is the fourth word in the previous sentence? A: day
# Pizza is the best food. Q: What is the first word in the previous sentence? A: Pizza
# I can tell a joke. Q: What is the fourth word in the previous sentence? A: a
# Trees offer me the refuge. Q: What is the fourth word in the previous sentence? Answer in one word only! A:
# Predicted token:  refuge
# Correct answer: the
# -----

# %%
valid_sentences
# Out:
# [[],
#  [],
#  [],
#  ['Jane brings me the book', 'Jane brings me a book'],
#  [],
#  ['Jane gives me the apple'],
#  ['Fish make me a happiest'],
#  ['Fish give me the smile'],
#  [],
#  [],
#  ['Tom buys me the gift'],
#  [],
#  ['Mary baked me the cake', 'Mary baked me a cake'],
#  ['Mary draws me a picture'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
correct_count / total_count
# Out:
# 0.025

# %%
accuracy_dict = {
    "first": 0.95,
    "second": 0.95,
    "third": 0.025,
    "fourth": 0.2,
}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.suptitle('Llama-3.3-70B-Instruct Accuracy by Article Position')
plt.title("Context Form: 'An artist Jane paints daily'")
plt.ylim(0, 1)
plt.bar(
    accuracy_dict.keys(),
    accuracy_dict.values(),
    color=["skyblue", "lightgreen", "salmon", "orange"],
)
# Out:
# <BarContainer object of 4 artists>

# %%
llama_valid_sentences = {
    "second": [
        ['Jack the boy runs fast'],
        ['Jack the student likes math'],
        ['Jack an actor plays well', 'Jack the actor plays well'],
        ['Jane the girl sings beautifully'],
        ['Jane a teacher helps kids', 'Jane the teacher helps kids'],
        ['Jane an artist paints daily', 'Jane the artist paints daily'],
        ['Fish the pet swims quickly'],
        ['Fish the creature needs water'],
        ['Fish an animal that swims', 'Fish the animal that swims'],
        ['Tom the man works hard'],
        ['Tom the friend visits often'],
        ['Tom an employee arrives early', 'Tom the employee arrives early'],
        ['Kate the woman cooks well'],
        ['Kate a nurse helps patients', 'Kate the nurse helps patients'],
        ['Kate an author writes books', 'Kate the author writes books'],
        ['Cars the vehicles move fast', 'Cars a vehicles move fast'],
        ['Cars a machine need fuel', 'Cars the machine need fuel'],
        ['Cars an invention changed society', 'Cars the invention changed society'],
        ['Trees the roots grow deep', 'Trees a roots grow deep'],
        []
    ],
    "third": [
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        [],
        ['Trees give the best shade'],
        ['Trees need the good forest']
    ],
    "fourth": [
        ['Jack gives me the ball'],
        ['Jack shows me the trick'],
        ['Jack tells me the idea'],
        [],
        [],
        ['Jane gives me the apple'],
        [],
        [],
        ['Fish bring me the escape'],
        [],
        [],
        ['Tom owes me the answer'],
        [],
        [],
        [],
        ['Cars cost me the most'],
        [],
        ['Cars offer me the option'],
        [],
        []
    ]
}

# %% [markdown]
# # Run Activation Patching

# %%
clean_prompt = PROMPT_TEMPLATE.format(article_first[0][0], "first")
print(clean_prompt)
patch_prompt = PROMPT_TEMPLATE.format(article_first[0][1], "first")
print(patch_prompt)
# Out:
# The boy Jack runs fast. Q: What is the first word in the previous sentence? Answer in one word only. A:
# A boy Jack runs fast. Q: What is the first word in the previous sentence? Answer in one word only. A:

# %%
clean_target_token_id = tokenizer.encode(clean_prompt, add_special_tokens=False)[0]
print(clean_target_token_id)
patch_target_token_id = tokenizer.encode(patch_prompt, add_special_tokens=False)[0]
print(patch_target_token_id)
# Out:
# 791
# 32

# %%
import os
os.chdir('/share/u/gio/mechinterp/')

# %%
clean_activations = []
with model.trace(clean_prompt):
    for l in range(model.config.num_hidden_layers):
        residual_output = model.model.layers[l].output[0].save()
        clean_activations.append(residual_output)
    logits = model.output.logits.save()
    clean_target_logits = model.output.logits[0, -1, clean_target_token_id].item().save()

clean_prediction = logits.argmax(dim=-1)[0, -1]
clean_token_prediction = model.tokenizer.decode(clean_prediction)
print(len(clean_activations), clean_token_prediction, clean_target_logits)
# Out:
# 32  The 12.856864929199219

# %%
patch_prompt
# Out:
# 'A boy Jack runs fast. Q: What is the first word in the previous sentence? Answer in one word only. A:'

# %%
with model.trace(patch_prompt):
    logits = model.output.logits.save()
    clean_target_logits_corrupt = model.output.logits[0, -1, clean_target_token_id].item().save()

corrupt_target_logits = logits[0, -1, patch_target_token_id].item()
corrupt_prediction = logits.argmax(dim=-1)[0, -1]
corrupt_token_prediction = model.tokenizer.decode(corrupt_prediction)
print(corrupt_target_logits, corrupt_token_prediction, clean_target_logits_corrupt)
# Out:
# 10.440034866333008  The 12.285228729248047

# %%
total_logit_diff = clean_target_logits - clean_target_logits_corrupt
print(f"Baseline logit difference (clean - corrupt): {total_logit_diff}")
# Out:
# Baseline logit difference (clean - corrupt): 3.975156784057617

# %%
clean_input_ids = model.tokenizer.encode(clean_prompt)
corrupt_input_ids = model.tokenizer.encode(patch_prompt)

# %%
from tqdm import trange

patched_activations = []
