# %%
# !pip install -q huggingface_hub

# %%
# !pip install hf_xet
# !pip install ipywidgets

# %%
# !pip install "huggingface_hub[hf_transfer]"
# !export HF_HUB_ENABLE_HF_TRANSFER=1   # or set in Python: os.environ[…] = "1"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from huggingface_hub import login
from tqdm import tqdm

# Replace with your actual token from https://huggingface.co/settings/tokens
login(token="")

# %%
from huggingface_hub import snapshot_download
from transformers import AutoTokenizer
import os

model_name = 'meta-llama/Llama-3.1-8B'
local_dir = "models/meta-llama/Llama-3.1-8B"

# Create directory if it doesn't exist
os.makedirs(local_dir, exist_ok=True)

# Download the entire repository with original safetensor files
print("Downloading model files...")
snapshot_download(
    repo_id=model_name,
    local_dir=local_dir,
    local_dir_use_symlinks=False,  # Download actual files, not symlinks
    tqdm_class=tqdm,  # Use tqdm for progress bars (already imported above)
    # resume_download=True,  # Resume if download was interrupted
)

print(f"Model downloaded to: {local_dir}")

# You can also download just the tokenizer if needed
# tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir=local_dir)
# Out:
# /opt/miniconda3/envs/retrieval-env/lib/python3.11/site-packages/huggingface_hub/file_download.py:980: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# ...
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# original/consolidated.00.pth:   0%|          | 0.00/16.1G [00:00<?, ?B/s]
# ...
